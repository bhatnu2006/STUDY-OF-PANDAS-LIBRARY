# %% [markdown]
# ## EXPERIMENT 9
# ## NEHA BHAT A2-25070123032
# ## STUDY OF PANDAS LIBRARY

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# CREATE A DATAFRAME
data={
    "NAME":["Neha","Gayatri","Atharva"],
    "MARKS":[90,91,85]
}
df = pd.DataFrame(data)
df
# Out:
#       NAME  MARKS
# 0     Neha     90
# 1  Gayatri     91
# 2  Atharva     85

# %%
# FIND THE STRUCTURE OF THE DATAFRAME

df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
# DISPLAY COLUMN NAMES
df.columns
# Out:
# Index(['NAME', 'MARKS'], dtype='object')

# %%
# CHECK DATA TYPS FOR  EACH COLUMN
df.dtypes
# Out:
# NAME     object
# MARKS     int64
# dtype: object

# %%
# ACCESS THE INDIVIDUAL COLUMN
df["NAME"]
# Out:
# 0       Neha
# 1    Gayatri
# 2    Atharva
# Name: NAME, dtype: object

# %%
df["MARKS"]
# Out:
# 0    90
# 1    91
# 2    85
# Name: MARKS, dtype: int64

# %%
df.loc[0]
# Out:
# NAME     Neha
# MARKS      90
# Name: 0, dtype: object

# %%
# ADD A NEW COLUMN
df["GRADE"]=["FIRST CLASS ","DISTINCTION","SECOND CLASS"]
df
# Out:
#       NAME  MARKS         GRADE
# 0     Neha     90  FIRST CLASS
# 1  Gayatri     91   DISTINCTION
# 2  Atharva     85  SECOND CLASS

# %%
# UPDATE DATA IN DATAFRAME
# CHANGE MARKS OF STUDENT
df.loc[0,"MARKS"]=98
df
# Out:
#       NAME  MARKS         GRADE
# 0     Neha     98  FIRST CLASS
# 1  Gayatri     91   DISTINCTION
# 2  Atharva     85  SECOND CLASS

# %%
# DELETE A COLUMN
df.drop("GRADE",axis=1,inplace=True)
df
# Out:
#       NAME  MARKS
# 0     Neha     98
# 1  Gayatri     91
# 2  Atharva     85

# %%
# PERFORM BSIC STATISTICAL ANALYSIS
mean1=df["MARKS"].mean()
mean1
# Out:
# np.float64(91.33333333333333)

# %%
min1=df["MARKS"].min()
min1
# Out:
# 85

# %%
max1=df["MARKS"].max()
max1
# Out:
# 98

# %%
# APPLY CONDITION (FILTERING)
# DISPLAY STUDENTS SCORING MORE THAN 86
df[df["MARKS"]>86]
# Out:
#       NAME  MARKS
# 0     Neha     98
# 1  Gayatri     91
